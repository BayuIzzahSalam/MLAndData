# %%
import pandas as pd
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-2df24be6-c8d8-432d-b244-a029ca46a99b" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-2df24be6-c8d8-432d-b244-a029ca46a99b">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving all_wc_18_players_fifa.csv to all_wc_18_players_fifa.csv

# %%
df = pd.read_csv('all_wc_18_players_fifa.csv')
df.head()
# Out:
#         team  number position  ...        age                name caps
# 0  Argentina       1       GK  ...  32.339726       Nahuel Guzmán    6
# 1  Argentina       2       DF  ...  31.241096     Gabriel Mercado   20
# 2  Argentina       3       DF  ...  25.786301  Nicolás Tagliafico    4
# 3  Argentina       4       DF  ...  31.731507    Cristian Ansaldi    5
# 4  Argentina       5       MF  ...  32.369863        Lucas Biglia   57
#
# [5 rows x 12 columns]

# %%
df.tail()
# Out:
#         team  number position  ...        age                    name caps
# 731  Uruguay      19       DF  ...  27.684932        Sebastián Coates   30
# 732  Uruguay      20       FW  ...  28.238356  Jonathan Urretaviscaya    4
# 733  Uruguay      21       FW  ...  31.328767          Edinson Cavani  101
# 734  Uruguay      22       DF  ...  31.186301          Martín Cáceres   76
# 735  Uruguay      23       GK  ...  35.221918            Martín Silva   11
#
# [5 rows x 12 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 736 entries, 0 to 735
# Data columns (total 12 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   team        736 non-null    object
#  1   number      736 non-null    int64
#  2   position    736 non-null    object
#  3   birth_date  736 non-null    object
#  4   shirt_name  736 non-null    object
#  5   club        736 non-null    object
#  6   height      736 non-null    int64
#  7   weight      736 non-null    int64
#  8   league      736 non-null    object
#  9   age         736 non-null    float64
#  10  name        736 non-null    object
#  11  caps        736 non-null    int64
# dtypes: float64(1), int64(4), object(7)
# memory usage: 69.1+ KB

# %%
#onehotencoding
encoded = pd.get_dummies(df)

# %%
encoded
# Out:
#      number  height  ...  name_Łukasz Teodorczyk  name_Šime Vrsaljko
# 0         1     192  ...                       0                   0
# 1         2     181  ...                       0                   0
# 2         3     169  ...                       0                   0
# 3         4     181  ...                       0                   0
# 4         5     175  ...                       0                   0
# ..      ...     ...  ...                     ...                 ...
# 731      19     196  ...                       0                   0
# 732      20     172  ...                       0                   0
# 733      21     188  ...                       0                   0
# 734      22     178  ...                       0                   0
# 735      23     187  ...                       0                   0
#
# [736 rows x 2548 columns]

# %%
#shape of data frame after encoding
encoded.shape
# Out:
# (736, 2548)
